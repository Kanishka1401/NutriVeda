# %%
# !pip install -q google-generativeai

# %%
import os
import google.generativeai as genai

# Put your Gemini API key here
os.environ["GEMINI_API_KEY"] = "AIzaSyBkewIzUIMcjUKC3YBq0XTZCFt39BVkzdQ"

# Configure client
genai.configure(api_key=os.environ["GEMINI_API_KEY"])

# %%
model = genai.GenerativeModel("gemini-1.5-flash")   # or "gemini-1.5-pro"

prompt = "Generate a 1-day vegetarian diet plan with breakfast, lunch, dinner, and snacks under 1800 calories."

response = model.generate_content(prompt)

print(response.text)
# Out:
# ## 1-Day Vegetarian Diet Plan (Under 1800 Calories)
#
# This plan focuses on whole, unprocessed foods and provides a balance of carbohydrates, protein, and healthy fats. Calorie counts are estimates and can vary based on specific ingredients and portion sizes.
#
# **Breakfast (Approx. 350 calories):**
#
# * **Overnight Oats:** ½ cup rolled oats, 1 cup unsweetened almond milk, 1 tbsp chia seeds, ½ cup berries (strawberries, blueberries, raspberries), 1 tsp honey or maple syrup (optional).  This provides sustained energy and fiber.
#
# **Mid-Morning Snack (Approx. 150 calories):**
#
# * **Apple slices with 2 tablespoons almond butter:**  Provides fiber, healthy fats, and protein to keep you satisfied until lunch.
#
#
# **Lunch (Approx. 450 calories):**
#
# * **Large Salad with Quinoa:** 1 cup cooked quinoa, 2 cups mixed greens, ½ cup chopped cucumber, ½ cup cherry tomatoes, ½ avocado, 2 oz crumbled feta cheese (optional, adds calories), 2 tbsp olive oil and vinegar dressing. Quinoa provides protein, while the vegetables and healthy fats contribute to satiety.
#
#
# **Afternoon Snack (Approx. 100 calories):**
#
# * **Small handful of almonds (about 15-20):** Healthy fats and protein to prevent energy crashes.
#
#
# **Dinner (Approx. 600 calories):**
#
# * **Vegetarian Chili:** 1.5 cups vegetarian chili (made with beans, lentils, vegetables, and spices). Serve with ½ cup brown rice.  This is a hearty and protein-rich meal, providing sustained energy.  You can control the sodium and oil content by making it yourself.
#
#
# **Evening Snack (Optional, Approx. 150 calories):**
#
# * **Air-popped popcorn (3 cups):** A low-calorie, high-fiber snack if you're still slightly hungry.  Avoid excessive butter or salt.
#
#
# **Total Estimated Calories:  Around 1700-1800 calories.**
#
#
# **Important Considerations:**
#
# * **Hydration:** Drink plenty of water throughout the day.
# * **Portion Control:**  Adjust portion sizes to meet your individual caloric needs.
# * **Variety:** This is just a sample plan.  Feel free to substitute ingredients with other healthy vegetarian options.
# * **Individual Needs:**  This plan is a general guideline. Consult a registered dietitian or nutritionist for personalized dietary advice, especially if you have any underlying health conditions.
#
#
# This plan provides a good balance of nutrients, but remember that individual needs vary.  Listen to your body's hunger cues and adjust accordingly.  Enjoy your delicious and healthy vegetarian day!

# %%
def llm_generate_diet_plan(patient, days=14):
    model = genai.GenerativeModel("gemini-1.5-flash")

    prompt = f"""
    Generate a {days}-day personalized Ayurvedic diet plan.

    Patient Information:
    - Name: {patient['name']}
    - Age: {patient['age']}
    - Gender: {patient['gender']}
    - Dosha: {patient['dosha']}
    - Height: {patient.get('height')}
    - Weight: {patient.get('weight')}
    - BMI: {patient.get('bmi')}
    - Digestion: {patient.get('digestion')}
    - Water Intake: {patient.get('waterIntake')}
    - Allergies: {patient.get('allergies')}
    - Condition: {patient.get('condition')}
    - Region: {patient.get('region')}
    - Cuisine Preference: {patient.get('cuisinePreference')}

    Rules:
    1. MUST output **valid JSON only** (no markdown, no text outside JSON).
    2. Include 14 days, each with Breakfast, Lunch, Dinner, and Snacks.
    3. Each meal must include approximate calories.
    4. Ensure **no meal or recipe is repeated across any of the 14 days**.
    5. Meals must align with the patient’s cuisine preference and dietary restrictions.
    6. Use **realistic portion sizes**:
       - Rotis/chapatis/parathas → measured in *pieces* (e.g., "2 rotis").
       - Sabzi, dal, curry, rice, khichdi, soups → measured in *bowls* or *cups* (e.g., "1 bowl of dal", "1 cup rice", "1 bowl vegetable stew").
       - Drinks (tea, milk, buttermilk) → measured in *cups* or *glasses*.
       - Dry snacks (nuts, seeds, fruits) → measured in *handfuls* or *pieces*.
    7. Example structure:
    {{
      "Day 1": {{
        "breakfast": "2 moong dal cheelas with chutney (approx. 300 calories)",
        "lunch": "1 bowl vegetable khichdi + 1 cup curd (approx. 400 calories)",
        "dinner": "2 rotis + 1 bowl palak paneer (approx. 450 calories)",
        "snacks": "a handful of almonds + 1 cup buttermilk (approx. 200 calories)",
        "total_calories": 1350
      }},
      "Day 2": {{ ... }}
    }}
    """

    response = model.generate_content(prompt)
    return response.text

# %%
# Example patient input
patient = {
    "name": "Ananya Sharma",
    "age": 80,
    "gender": "female",
    "dosha": "pitta-kapha",
    "height": 162,
    "weight": 58,
    "bmi": 22.1,
    "digestion": "weak",
    "waterIntake": 2.0,
    "allergies": ["gluten"],
    "condition": "none",
    "region": "India",
    "cuisinePreference": "maharastrian",
    "clinicalNotes": "Prefers light dinners"
}

plan_text = llm_generate_diet_plan(patient, days=14)
print(plan_text)
# Out:
# ```json
# {
#   "Day 1": {
#     "breakfast": "1 bowl Vegetable Upma with coconut (approx. 350 calories)",
#     "lunch": "2 Misal Pav (gluten-free pav) with a side of curd (approx. 450 calories)",
#     "dinner": "2 rotis + 1 bowl mixed vegetable sabzi (approx. 400 calories)",
#     "snacks": "1 apple + a small bowl of mixed nuts (approx. 200 calories)",
#     "total_calories": 1400
#   },
#   "Day 2": {
#     "breakfast": "2 Gluten-free Oats porridge with milk and banana (approx. 300 calories)",
#     "lunch": "1 bowl Moong Dal Khichdi + 1/2 cup mango slices (approx. 350 calories)",
#     "dinner": "1 bowl Bhindi Masala + 2 rotis (approx. 400 calories)",
#     "snacks": "1 glass buttermilk + a handful of sunflower seeds (approx. 150 calories)",
#     "total_calories": 1200
#   },
#   "Day 3": {
#     "breakfast": "1 cup rice porridge with milk and a sprinkle of ginger (approx. 250 calories)",
#     "lunch": "1 bowl Vegetable Stew + 1 chapati (approx. 300 calories)",
#     "dinner": "1 bowl Masoor Dal + 1 bowl mixed vegetable curry + 1 roti (approx. 350 calories)",
#     "snacks": "a small bowl of pomegranate seeds (approx. 100 calories)",
#     "total_calories": 1000
#   },
#   "Day 4": {
#     "breakfast": "1 bowl Besan Chilla with coconut chutney (approx. 320 calories)",
#     "lunch": "1 bowl Kolhapuri style Mutton curry (without spices) + 1 roti (approx. 420 calories)",
#     "dinner": "1 bowl of Dal Tadka + 2 rotis (approx. 400 calories)",
#     "snacks": "1 pear + 1 cup of spiced milk (approx. 200 calories)",
#     "total_calories": 1340
#   },
#   "Day 5": {
#     "breakfast": "2 Gluten-free Idlis with coconut chutney (approx. 350 calories)",
#     "lunch": "1 bowl of Palak Paneer + 2 rotis (approx. 450 calories)",
#     "dinner": "1 bowl Tuar Dal + 1 bowl of Carrot and peas sabzi + 1 roti (approx. 380 calories)",
#     "snacks": "a small bowl of roasted peanuts (approx. 220 calories)",
#     "total_calories": 1400
#   },
#   "Day 6": {
#     "breakfast": "2 Gluten-free pancakes with fruit compote (approx. 300 calories)",
#     "lunch": "1 bowl of mixed vegetable khichdi (approx. 350 calories)",
#     "dinner": "2 rotis + 1 bowl of Lauki Kofta (approx. 400 calories)",
#     "snacks": "1 banana + 1 glass buttermilk (approx. 200 calories)",
#     "total_calories": 1250
#   },
#   "Day 7": {
#     "breakfast": "1 bowl of Sweet potato Halwa (approx. 300 calories)",
#     "lunch": "1 bowl of chicken curry (mild) + 1 roti (approx. 400 calories)",
#     "dinner": "1 bowl of Rajma Masala + 1 roti (approx. 380 calories)",
#     "snacks": "handful of almonds and cashews (approx. 220 calories)",
#     "total_calories": 1300
#   },
#   "Day 8": {
#     "breakfast": "1 cup of Gluten-free Semolina porridge with milk (approx. 280 calories)",
#     "lunch": "1 bowl of Aloo Palak + 2 rotis (approx. 400 calories)",
#     "dinner": "1 bowl of Moong Dal Cheela (approx. 350 calories)",
#     "snacks": "1 orange + 1 cup tea (approx. 170 calories)",
#     "total_calories": 1200
#   },
#   "Day 9": {
#     "breakfast": "2 Dosa (gluten free batter) with coconut chutney (approx. 350 calories)",
#     "lunch": "1 bowl of mixed vegetable curry + rice (approx. 420 calories)",
#     "dinner": "1 bowl of Dal Makhani + 1 roti (approx. 380 calories)",
#     "snacks": "a handful of pumpkin seeds (approx. 150 calories)",
#     "total_calories": 1300
#   },
#   "Day 10": {
#     "breakfast": "1 bowl of Rava Upma (approx. 320 calories)",
#     "lunch": "1 bowl of Baingan Bharta + 2 rotis (approx. 400 calories)",
#     "dinner": "1 bowl of Vegetable Pulao (approx. 380 calories)",
#     "snacks": "1 apple and a small bowl of walnuts (approx. 200 calories)",
#     "total_calories": 1300
#   },
#   "Day 11": {
#     "breakfast": "1 bowl of Vegetable Omelette (approx. 300 calories)",
#     "lunch": "1 bowl of Fish curry (mild spices) + 1 roti (approx. 450 calories)",
#     "dinner": "1 bowl of Mixed Vegetable Curry + 2 rotis (approx. 400 calories)",
#     "snacks": "1 cup of mango smoothie (approx. 250 calories)",
#     "total_calories": 1400
#   },
#   "Day 12": {
#     "breakfast": "1 bowl of Poha (approx. 300 calories)",
#     "lunch": "1 bowl of Soyabean Curry + 2 rotis (approx. 400 calories)",
#     "dinner": "1 bowl of Gobi Manchurian (without excess oil) + 1 roti (approx. 350 calories)",
#     "snacks": "a handful of pistachios (approx. 200 calories)",
#     "total_calories": 1250
#   },
#   "Day 13": {
#     "breakfast": "2 Gluten-free parathas with curd (approx. 350 calories)",
#     "lunch": "1 bowl of Dal Fry + 1 bowl of rice (approx. 400 calories)",
#     "dinner": "1 bowl of Aloo Gobi + 2 rotis (approx. 400 calories)",
#     "snacks": "1 glass buttermilk + a handful of raisins (approx. 150 calories)",
#     "total_calories": 1300
#   },
#   "Day 14": {
#     "breakfast": "1 bowl of Bread Upma (gluten-free bread) (approx. 300 calories)",
#     "lunch": "1 bowl of Kadhi (without spices) + 2 rotis (approx. 400 calories)",
#     "dinner": "1 bowl of Vegetable Biryani (approx. 400 calories)",
#     "snacks": "1 small bowl of mixed fruits (approx. 150 calories)",
#     "total_calories": 1250
#   }
# }
# ```
